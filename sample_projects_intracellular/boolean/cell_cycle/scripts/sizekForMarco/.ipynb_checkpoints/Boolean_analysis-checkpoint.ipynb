# %%
import numpy as np
import seaborn as sns

import ginsim
import biolqm
import maboss
from itertools import combinations # for iterating over sets
import matplotlib.pyplot as plt # for modifying plots
import pandas as pd # for the visualization of lists of states
import pydot

import os

from tools import load_trajs, draw_graph_from_pandas, compute_circuits, compute_stg_counts

# %%
path = "/home/marco/Documents/PhD/PhysiBoSS/sample_projects_intracellular/boolean/cell_cycle/config/boolean_network/"

# %%
bnd_file = path + "sizek.bnd"
cfg_file = path + "sizek_sustained.cfg"

masim = maboss.load(bnd_file, cfg_file)

# %%
#Wild type

sim = masim.copy()

outputs = ["CyclinA", "CyclinB", "CyclinE", "CyclinD1", "Cdc20", "E2F1", "Cdh1"]

outputs = ["CyclinA", "CyclinB", "CyclinE", "CyclinD1"]

sim.network.set_output(outputs)

model = sim.run()

model.plot_piechart()
# Out:
# /home/marco/anaconda3/envs/MaBoSS_env/lib/python3.9/site-packages/maboss/figures.py:86: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
#   ax.pie(plot_line, labels=plotting_labels, radius=1.2,

# %%
model.plot_trajectory()

# %%
## Discrete time
WT_phenotypes_discrete = sim.copy()
WT_phenotypes_discrete.update_parameters(discrete_time=1, time_tick=1, max_time=150)

# %%
# %time res_discrete = WT_phenotypes_discrete.run()
# Out:
# CPU times: user 6.93 ms, sys: 0 ns, total: 6.93 ms
# Wall time: 315 ms

# %%
res_discrete.plot_node_trajectory()

# %%
bnd_file = path + "sizek_phenotypes.bnd"
cfg_file = path + "sizek_sustained_phenotypes.cfg"

sim_phenotypes = maboss.load(bnd_file, cfg_file)

# %%
WT_phenotypes = sim_phenotypes.copy()

WT_result = WT_phenotypes.run()

# %%
WT_result.plot_trajectory()

# %%
WT_result.plot_piechart()

# %%
# %time res = WT_phenotypes.run()
res.plot_node_trajectory()
# Out:
# CPU times: user 0 ns, sys: 8.92 ms, total: 8.92 ms
# Wall time: 3.97 s

# %%
## Discrete time
WT_phenotypes_discrete = WT_phenotypes.copy()
WT_phenotypes_discrete.update_parameters(discrete_time=1, time_tick=1, max_time=100)

# %%
# %time res_discrete = WT_phenotypes_discrete.run()
# Out:
# CPU times: user 4.18 ms, sys: 8.02 ms, total: 12.2 ms
# Wall time: 211 ms

# %%
res_discrete.plot_trajectory()

# %%
res_discrete.plot_node_trajectory()

# %%
WT_phenotypes_trajs = WT_phenotypes.copy()
WT_phenotypes_trajs.update_parameters(display_traj=1, thread_count=1)

# %%
# %time res_trajs = WT_phenotypes_trajs.run()
# Out:
# CPU times: user 4.1 ms, sys: 60.4 ms, total: 64.5 ms
# Wall time: 27.1 s

# %%
outputs = ["CyclinA", "CyclinB", "CyclinE", "CyclinD1"]
outputs_phenotype = ["G0G1_exit", "G2_exit", "S_exit", "M_exit"]
trajs, all_states = load_trajs(res_trajs._path, outputs_phenotype, )
stg_counts, state_ids, ids_state = compute_stg_counts(trajs, all_states)

# %%
data = pd.DataFrame(
    data=stg_counts,
    index=state_ids.keys(), columns=state_ids.keys()
)
data
# Out:
#                                            <nil>  G0G1_exit  \
# <nil>                                        0.0     5755.0
# G0G1_exit                                 4779.0        0.0
# G0G1_exit -- G2_exit                         0.0     2106.0
# G0G1_exit -- G2_exit -- M_exit               0.0        0.0
# G0G1_exit -- G2_exit -- M_exit -- S_exit     0.0        0.0
# G0G1_exit -- G2_exit -- S_exit               0.0        0.0
# G0G1_exit -- M_exit                          0.0      404.0
# G0G1_exit -- M_exit -- S_exit                0.0        0.0
# G0G1_exit -- S_exit                          0.0     9563.0
# G2_exit                                   1912.0        0.0
# G2_exit -- M_exit                            0.0        0.0
# G2_exit -- M_exit -- S_exit                  0.0        0.0
# G2_exit -- S_exit                            0.0        0.0
# M_exit                                     459.0        0.0
# M_exit -- S_exit                             0.0        0.0
# S_exit                                    1669.0        0.0
#
#                                           G0G1_exit -- G2_exit  \
# <nil>                                                      0.0
# G0G1_exit                                               4769.0
# G0G1_exit -- G2_exit                                       0.0
# G0G1_exit -- G2_exit -- M_exit                           694.0
# G0G1_exit -- G2_exit -- M_exit -- S_exit                   0.0
# G0G1_exit -- G2_exit -- S_exit                          2813.0
# G0G1_exit -- M_exit                                        0.0
# G0G1_exit -- M_exit -- S_exit                              0.0
# G0G1_exit -- S_exit                                        0.0
# G2_exit                                                 3628.0
# G2_exit -- M_exit                                          0.0
# G2_exit -- M_exit -- S_exit                                0.0
# G2_exit -- S_exit                                          0.0
# M_exit                                                     0.0
# M_exit -- S_exit                                           0.0
# S_exit                                                     0.0
#
#                                           G0G1_exit -- G2_exit -- M_exit  \
# <nil>                                                                0.0
# G0G1_exit                                                            0.0
# G0G1_exit -- G2_exit                                              1626.0
# G0G1_exit -- G2_exit -- M_exit                                       0.0
# G0G1_exit -- G2_exit -- M_exit -- S_exit                            57.0
# G0G1_exit -- G2_exit -- S_exit                                       0.0
# G0G1_exit -- M_exit                                                 27.0
# G0G1_exit -- M_exit -- S_exit                                        0.0
# G0G1_exit -- S_exit                                                  0.0
# G2_exit                                                              0.0
# G2_exit -- M_exit                                                  289.0
# G2_exit -- M_exit -- S_exit                                          0.0
# G2_exit -- S_exit                                                    0.0
# M_exit                                                               0.0
# M_exit -- S_exit                                                     0.0
# S_exit                                                               0.0
#
#                                           G0G1_exit -- G2_exit -- M_exit -- S_exit  \
# <nil>                                                                          0.0
# G0G1_exit                                                                      0.0
# G0G1_exit -- G2_exit                                                           0.0
# G0G1_exit -- G2_exit -- M_exit                                               636.0
# G0G1_exit -- G2_exit -- M_exit -- S_exit                                       0.0
# G0G1_exit -- G2_exit -- S_exit                                              2095.0
# G0G1_exit -- M_exit                                                            0.0
# G0G1_exit -- M_exit -- S_exit                                                 22.0
# G0G1_exit -- S_exit                                                            0.0
# G2_exit                                                                        0.0
# G2_exit -- M_exit                                                              0.0
# G2_exit -- M_exit -- S_exit                                                   67.0
# G2_exit -- S_exit                                                              0.0
# M_exit                                                                         0.0
# M_exit -- S_exit                                                               0.0
# S_exit                                                                         0.0
#
#                                           G0G1_exit -- G2_exit -- S_exit  \
# <nil>                                                                0.0
# G0G1_exit                                                            0.0
# G0G1_exit -- G2_exit                                              3998.0
# G0G1_exit -- G2_exit -- M_exit                                       0.0
# G0G1_exit -- G2_exit -- M_exit -- S_exit                          1676.0
# G0G1_exit -- G2_exit -- S_exit                                       0.0
# G0G1_exit -- M_exit                                                  0.0
# G0G1_exit -- M_exit -- S_exit                                        0.0
# G0G1_exit -- S_exit                                               3283.0
# G2_exit                                                              0.0
# G2_exit -- M_exit                                                    0.0
# G2_exit -- M_exit -- S_exit                                          0.0
# G2_exit -- S_exit                                                  398.0
# M_exit                                                               0.0
# M_exit -- S_exit                                                     0.0
# S_exit                                                               0.0
#
#                                           G0G1_exit -- M_exit  \
# <nil>                                                     0.0
# G0G1_exit                                                31.0
# G0G1_exit -- G2_exit                                      0.0
# G0G1_exit -- G2_exit -- M_exit                          513.0
# G0G1_exit -- G2_exit -- M_exit -- S_exit                  0.0
# G0G1_exit -- G2_exit -- S_exit                            0.0
# G0G1_exit -- M_exit                                       0.0
# G0G1_exit -- M_exit -- S_exit                            31.0
# G0G1_exit -- S_exit                                       0.0
# G2_exit                                                   0.0
# G2_exit -- M_exit                                         0.0
# G2_exit -- M_exit -- S_exit                               0.0
# G2_exit -- S_exit                                         0.0
# M_exit                                                   75.0
# M_exit -- S_exit                                          0.0
# S_exit                                                    0.0
#
#                                           G0G1_exit -- M_exit -- S_exit  \
# <nil>                                                               0.0
# G0G1_exit                                                           0.0
# G0G1_exit -- G2_exit                                                0.0
# G0G1_exit -- G2_exit -- M_exit                                      0.0
# G0G1_exit -- G2_exit -- M_exit -- S_exit                         1076.0
# G0G1_exit -- G2_exit -- S_exit                                      0.0
# G0G1_exit -- M_exit                                               174.0
# G0G1_exit -- M_exit -- S_exit                                       0.0
# G0G1_exit -- S_exit                                                28.0
# G2_exit                                                             0.0
# G2_exit -- M_exit                                                   0.0
# G2_exit -- M_exit -- S_exit                                         0.0
# G2_exit -- S_exit                                                   0.0
# M_exit                                                              0.0
# M_exit -- S_exit                                                   20.0
# S_exit                                                              0.0
#
#                                           G0G1_exit -- S_exit  G2_exit  \
# <nil>                                                     0.0   1816.0
# G0G1_exit                                              8205.0      0.0
# G0G1_exit -- G2_exit                                      0.0   4142.0
# G0G1_exit -- G2_exit -- M_exit                            0.0      0.0
# G0G1_exit -- G2_exit -- M_exit -- S_exit                  0.0      0.0
# G0G1_exit -- G2_exit -- S_exit                         3999.0      0.0
# G0G1_exit -- M_exit                                       0.0      0.0
# G0G1_exit -- M_exit -- S_exit                          1241.0      0.0
# G0G1_exit -- S_exit                                       0.0      0.0
# G2_exit                                                   0.0      0.0
# G2_exit -- M_exit                                         0.0    685.0
# G2_exit -- M_exit -- S_exit                               0.0      0.0
# G2_exit -- S_exit                                         0.0    718.0
# M_exit                                                    0.0      0.0
# M_exit -- S_exit                                          0.0      0.0
# S_exit                                                 1762.0      0.0
#
#                                           G2_exit -- M_exit  \
# <nil>                                                   0.0
# G0G1_exit                                               0.0
# G0G1_exit -- G2_exit                                    0.0
# G0G1_exit -- G2_exit -- M_exit                        155.0
# G0G1_exit -- G2_exit -- M_exit -- S_exit                0.0
# G0G1_exit -- G2_exit -- S_exit                          0.0
# G0G1_exit -- M_exit                                     0.0
# G0G1_exit -- M_exit -- S_exit                           0.0
# G0G1_exit -- S_exit                                     0.0
# G2_exit                                              1364.0
# G2_exit -- M_exit                                       0.0
# G2_exit -- M_exit -- S_exit                            13.0
# G2_exit -- S_exit                                       0.0
# M_exit                                                 14.0
# M_exit -- S_exit                                        0.0
# S_exit                                                  0.0
#
#                                           G2_exit -- M_exit -- S_exit  \
# <nil>                                                             0.0
# G0G1_exit                                                         0.0
# G0G1_exit -- G2_exit                                              0.0
# G0G1_exit -- G2_exit -- M_exit                                    0.0
# G0G1_exit -- G2_exit -- M_exit -- S_exit                          8.0
# G0G1_exit -- G2_exit -- S_exit                                    0.0
# G0G1_exit -- M_exit                                               0.0
# G0G1_exit -- M_exit -- S_exit                                     0.0
# G0G1_exit -- S_exit                                               0.0
# G2_exit                                                           0.0
# G2_exit -- M_exit                                                71.0
# G2_exit -- M_exit -- S_exit                                       0.0
# G2_exit -- S_exit                                                61.0
# M_exit                                                            0.0
# M_exit -- S_exit                                                  0.0
# S_exit                                                            0.0
#
#                                           G2_exit -- S_exit  M_exit  \
# <nil>                                                   0.0    13.0
# G0G1_exit                                               0.0     0.0
# G0G1_exit -- G2_exit                                    0.0     0.0
# G0G1_exit -- G2_exit -- M_exit                          0.0     0.0
# G0G1_exit -- G2_exit -- M_exit -- S_exit                0.0     0.0
# G0G1_exit -- G2_exit -- S_exit                        427.0     0.0
# G0G1_exit -- M_exit                                     0.0    45.0
# G0G1_exit -- M_exit -- S_exit                           0.0     0.0
# G0G1_exit -- S_exit                                     0.0     0.0
# G2_exit                                               433.0     0.0
# G2_exit -- M_exit                                       0.0   500.0
# G2_exit -- M_exit -- S_exit                            37.0     0.0
# G2_exit -- S_exit                                       0.0     0.0
# M_exit                                                  0.0     0.0
# M_exit -- S_exit                                        0.0     5.0
# S_exit                                                373.0     0.0
#
#                                           M_exit -- S_exit  S_exit
# <nil>                                                  0.0  1466.0
# G0G1_exit                                              0.0     0.0
# G0G1_exit -- G2_exit                                   0.0     0.0
# G0G1_exit -- G2_exit -- M_exit                         0.0     0.0
# G0G1_exit -- G2_exit -- M_exit -- S_exit               0.0     0.0
# G0G1_exit -- G2_exit -- S_exit                         0.0     0.0
# G0G1_exit -- M_exit                                    0.0     0.0
# G0G1_exit -- M_exit -- S_exit                          4.0     0.0
# G0G1_exit -- S_exit                                    0.0  2235.0
# G2_exit                                                0.0     0.0
# G2_exit -- M_exit                                      0.0     0.0
# G2_exit -- M_exit -- S_exit                           23.0     0.0
# G2_exit -- S_exit                                      0.0    91.0
# M_exit                                                15.0     0.0
# M_exit -- S_exit                                       0.0    18.0
# S_exit                                                 1.0     0.0

# %%
draw_graph_from_pandas(data)

# %%
probas = pd.DataFrame(
    data=np.divide(stg_counts,stg_counts.sum(axis=1)[:, np.newaxis]), 
    index=state_ids.keys(), columns=state_ids.keys()
)
probas
# Out:
#                                              <nil>  G0G1_exit  \
# <nil>                                     0.000000   0.635912
# G0G1_exit                                 0.268725   0.000000
# G0G1_exit -- G2_exit                      0.000000   0.177392
# G0G1_exit -- G2_exit -- M_exit            0.000000   0.000000
# G0G1_exit -- G2_exit -- M_exit -- S_exit  0.000000   0.000000
# G0G1_exit -- G2_exit -- S_exit            0.000000   0.000000
# G0G1_exit -- M_exit                       0.000000   0.621538
# G0G1_exit -- M_exit -- S_exit             0.000000   0.000000
# G0G1_exit -- S_exit                       0.000000   0.632934
# G2_exit                                   0.260597   0.000000
# G2_exit -- M_exit                         0.000000   0.000000
# G2_exit -- M_exit -- S_exit               0.000000   0.000000
# G2_exit -- S_exit                         0.000000   0.000000
# M_exit                                    0.815275   0.000000
# M_exit -- S_exit                          0.000000   0.000000
# S_exit                                    0.438633   0.000000
#
#                                           G0G1_exit -- G2_exit  \
# <nil>                                                 0.000000
# G0G1_exit                                             0.268162
# G0G1_exit -- G2_exit                                  0.000000
# G0G1_exit -- G2_exit -- M_exit                        0.347347
# G0G1_exit -- G2_exit -- M_exit -- S_exit              0.000000
# G0G1_exit -- G2_exit -- S_exit                        0.301371
# G0G1_exit -- M_exit                                   0.000000
# G0G1_exit -- M_exit -- S_exit                         0.000000
# G0G1_exit -- S_exit                                   0.000000
# G2_exit                                               0.494480
# G2_exit -- M_exit                                     0.000000
# G2_exit -- M_exit -- S_exit                           0.000000
# G2_exit -- S_exit                                     0.000000
# M_exit                                                0.000000
# M_exit -- S_exit                                      0.000000
# S_exit                                                0.000000
#
#                                           G0G1_exit -- G2_exit -- M_exit  \
# <nil>                                                           0.000000
# G0G1_exit                                                       0.000000
# G0G1_exit -- G2_exit                                            0.136961
# G0G1_exit -- G2_exit -- M_exit                                  0.000000
# G0G1_exit -- G2_exit -- M_exit -- S_exit                        0.020234
# G0G1_exit -- G2_exit -- S_exit                                  0.000000
# G0G1_exit -- M_exit                                             0.041538
# G0G1_exit -- M_exit -- S_exit                                   0.000000
# G0G1_exit -- S_exit                                             0.000000
# G2_exit                                                         0.000000
# G2_exit -- M_exit                                               0.187055
# G2_exit -- M_exit -- S_exit                                     0.000000
# G2_exit -- S_exit                                               0.000000
# M_exit                                                          0.000000
# M_exit -- S_exit                                                0.000000
# S_exit                                                          0.000000
#
#                                           G0G1_exit -- G2_exit -- M_exit -- S_exit  \
# <nil>                                                                     0.000000
# G0G1_exit                                                                 0.000000
# G0G1_exit -- G2_exit                                                      0.000000
# G0G1_exit -- G2_exit -- M_exit                                            0.318318
# G0G1_exit -- G2_exit -- M_exit -- S_exit                                  0.000000
# G0G1_exit -- G2_exit -- S_exit                                            0.224448
# G0G1_exit -- M_exit                                                       0.000000
# G0G1_exit -- M_exit -- S_exit                                             0.016949
# G0G1_exit -- S_exit                                                       0.000000
# G2_exit                                                                   0.000000
# G2_exit -- M_exit                                                         0.000000
# G2_exit -- M_exit -- S_exit                                               0.478571
# G2_exit -- S_exit                                                         0.000000
# M_exit                                                                    0.000000
# M_exit -- S_exit                                                          0.000000
# S_exit                                                                    0.000000
#
#                                           G0G1_exit -- G2_exit -- S_exit  \
# <nil>                                                           0.000000
# G0G1_exit                                                       0.000000
# G0G1_exit -- G2_exit                                            0.336759
# G0G1_exit -- G2_exit -- M_exit                                  0.000000
# G0G1_exit -- G2_exit -- M_exit -- S_exit                        0.594959
# G0G1_exit -- G2_exit -- S_exit                                  0.000000
# G0G1_exit -- M_exit                                             0.000000
# G0G1_exit -- M_exit -- S_exit                                   0.000000
# G0G1_exit -- S_exit                                             0.217288
# G2_exit                                                         0.000000
# G2_exit -- M_exit                                               0.000000
# G2_exit -- M_exit -- S_exit                                     0.000000
# G2_exit -- S_exit                                               0.313880
# M_exit                                                          0.000000
# M_exit -- S_exit                                                0.000000
# S_exit                                                          0.000000
#
#                                           G0G1_exit -- M_exit  \
# <nil>                                                0.000000
# G0G1_exit                                            0.001743
# G0G1_exit -- G2_exit                                 0.000000
# G0G1_exit -- G2_exit -- M_exit                       0.256757
# G0G1_exit -- G2_exit -- M_exit -- S_exit             0.000000
# G0G1_exit -- G2_exit -- S_exit                       0.000000
# G0G1_exit -- M_exit                                  0.000000
# G0G1_exit -- M_exit -- S_exit                        0.023883
# G0G1_exit -- S_exit                                  0.000000
# G2_exit                                              0.000000
# G2_exit -- M_exit                                    0.000000
# G2_exit -- M_exit -- S_exit                          0.000000
# G2_exit -- S_exit                                    0.000000
# M_exit                                               0.133215
# M_exit -- S_exit                                     0.000000
# S_exit                                               0.000000
#
#                                           G0G1_exit -- M_exit -- S_exit  \
# <nil>                                                          0.000000
# G0G1_exit                                                      0.000000
# G0G1_exit -- G2_exit                                           0.000000
# G0G1_exit -- G2_exit -- M_exit                                 0.000000
# G0G1_exit -- G2_exit -- M_exit -- S_exit                       0.381967
# G0G1_exit -- G2_exit -- S_exit                                 0.000000
# G0G1_exit -- M_exit                                            0.267692
# G0G1_exit -- M_exit -- S_exit                                  0.000000
# G0G1_exit -- S_exit                                            0.001853
# G2_exit                                                        0.000000
# G2_exit -- M_exit                                              0.000000
# G2_exit -- M_exit -- S_exit                                    0.000000
# G2_exit -- S_exit                                              0.000000
# M_exit                                                         0.000000
# M_exit -- S_exit                                               0.465116
# S_exit                                                         0.000000
#
#                                           G0G1_exit -- S_exit   G2_exit  \
# <nil>                                                0.000000  0.200663
# G0G1_exit                                            0.461370  0.000000
# G0G1_exit -- G2_exit                                 0.000000  0.348888
# G0G1_exit -- G2_exit -- M_exit                       0.000000  0.000000
# G0G1_exit -- G2_exit -- M_exit -- S_exit             0.000000  0.000000
# G0G1_exit -- G2_exit -- S_exit                       0.428434  0.000000
# G0G1_exit -- M_exit                                  0.000000  0.000000
# G0G1_exit -- M_exit -- S_exit                        0.956086  0.000000
# G0G1_exit -- S_exit                                  0.000000  0.000000
# G2_exit                                              0.000000  0.000000
# G2_exit -- M_exit                                    0.000000  0.443366
# G2_exit -- M_exit -- S_exit                          0.000000  0.000000
# G2_exit -- S_exit                                    0.000000  0.566246
# M_exit                                               0.000000  0.000000
# M_exit -- S_exit                                     0.000000  0.000000
# S_exit                                               0.463075  0.000000
#
#                                           G2_exit -- M_exit  \
# <nil>                                              0.000000
# G0G1_exit                                          0.000000
# G0G1_exit -- G2_exit                               0.000000
# G0G1_exit -- G2_exit -- M_exit                     0.077578
# G0G1_exit -- G2_exit -- M_exit -- S_exit           0.000000
# G0G1_exit -- G2_exit -- S_exit                     0.000000
# G0G1_exit -- M_exit                                0.000000
# G0G1_exit -- M_exit -- S_exit                      0.000000
# G0G1_exit -- S_exit                                0.000000
# G2_exit                                            0.185907
# G2_exit -- M_exit                                  0.000000
# G2_exit -- M_exit -- S_exit                        0.092857
# G2_exit -- S_exit                                  0.000000
# M_exit                                             0.024867
# M_exit -- S_exit                                   0.000000
# S_exit                                             0.000000
#
#                                           G2_exit -- M_exit -- S_exit  \
# <nil>                                                        0.000000
# G0G1_exit                                                    0.000000
# G0G1_exit -- G2_exit                                         0.000000
# G0G1_exit -- G2_exit -- M_exit                               0.000000
# G0G1_exit -- G2_exit -- M_exit -- S_exit                     0.002840
# G0G1_exit -- G2_exit -- S_exit                               0.000000
# G0G1_exit -- M_exit                                          0.000000
# G0G1_exit -- M_exit -- S_exit                                0.000000
# G0G1_exit -- S_exit                                          0.000000
# G2_exit                                                      0.000000
# G2_exit -- M_exit                                            0.045955
# G2_exit -- M_exit -- S_exit                                  0.000000
# G2_exit -- S_exit                                            0.048107
# M_exit                                                       0.000000
# M_exit -- S_exit                                             0.000000
# S_exit                                                       0.000000
#
#                                           G2_exit -- S_exit    M_exit  \
# <nil>                                              0.000000  0.001436
# G0G1_exit                                          0.000000  0.000000
# G0G1_exit -- G2_exit                               0.000000  0.000000
# G0G1_exit -- G2_exit -- M_exit                     0.000000  0.000000
# G0G1_exit -- G2_exit -- M_exit -- S_exit           0.000000  0.000000
# G0G1_exit -- G2_exit -- S_exit                     0.045747  0.000000
# G0G1_exit -- M_exit                                0.000000  0.069231
# G0G1_exit -- M_exit -- S_exit                      0.000000  0.000000
# G0G1_exit -- S_exit                                0.000000  0.000000
# G2_exit                                            0.059016  0.000000
# G2_exit -- M_exit                                  0.000000  0.323625
# G2_exit -- M_exit -- S_exit                        0.264286  0.000000
# G2_exit -- S_exit                                  0.000000  0.000000
# M_exit                                             0.000000  0.000000
# M_exit -- S_exit                                   0.000000  0.116279
# S_exit                                             0.098029  0.000000
#
#                                           M_exit -- S_exit    S_exit
# <nil>                                             0.000000  0.161989
# G0G1_exit                                         0.000000  0.000000
# G0G1_exit -- G2_exit                              0.000000  0.000000
# G0G1_exit -- G2_exit -- M_exit                    0.000000  0.000000
# G0G1_exit -- G2_exit -- M_exit -- S_exit          0.000000  0.000000
# G0G1_exit -- G2_exit -- S_exit                    0.000000  0.000000
# G0G1_exit -- M_exit                               0.000000  0.000000
# G0G1_exit -- M_exit -- S_exit                     0.003082  0.000000
# G0G1_exit -- S_exit                               0.000000  0.147925
# G2_exit                                           0.000000  0.000000
# G2_exit -- M_exit                                 0.000000  0.000000
# G2_exit -- M_exit -- S_exit                       0.164286  0.000000
# G2_exit -- S_exit                                 0.000000  0.071767
# M_exit                                            0.026643  0.000000
# M_exit -- S_exit                                  0.000000  0.418605
# S_exit                                            0.000263  0.000000

# %%
# %time paths_dict = compute_circuits(probas, ids_state, '<nil>', 0)
# Out:
# CPU times: user 15.6 s, sys: 7.89 ms, total: 15.6 s
# Wall time: 15.6 s

# %%
for proba in sorted(paths_dict, reverse=True):
    if proba > 0.01:
        print("%.2f : %s" % (proba, paths_dict[proba]))
# Out:
# 0.17 : ['<nil>', 'G0G1_exit']
# 0.07 : ['<nil>', 'S_exit']
# 0.05 : ['<nil>', 'G2_exit']
# 0.02 : ['<nil>', 'G0G1_exit', 'G0G1_exit -- S_exit', 'S_exit']
# 0.02 : ['<nil>', 'G0G1_exit', 'G0G1_exit -- G2_exit', 'G2_exit']
# 0.01 : ['<nil>', 'S_exit', 'G0G1_exit -- S_exit', 'G0G1_exit']
